# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticks
import seaborn as sns
import missingno as miss
import datetime as dt
import statsmodels.tsa.api as tsa

# %%
df = pd.read_csv("Crimes_-_2001_to_Present.csv", low_memory=False)
df
# Out:
#                ID Case Number                    Date  \
# 0         5741943    HN549294  08/25/2007 09:22:18 AM
# 1           25953    JE240540  05/24/2021 03:06:00 PM
# 2           26038    JE279849  06/26/2021 09:24:00 AM
# 3        13279676    JG507211  11/09/2023 07:30:00 AM
# 4        13274752    JG501049  11/12/2023 07:59:00 AM
# ...           ...         ...                     ...
# 2611256   4824792    HM301261  04/20/2006 02:15:00 AM
# 2611257   4904125    HM518531  08/04/2006 02:00:00 AM
# 2611258   4880488    HM494450  07/23/2006 07:00:30 PM
# 2611259   4895338    HM510513  07/29/2006 02:30:00 PM
# 2611260   4863185    HM476512                     NaN
#
#                              Block  IUCR Primary Type  \
# 0               074XX N ROGERS AVE  0560      ASSAULT
# 1              020XX N LARAMIE AVE  0110     HOMICIDE
# 2            062XX N MC CORMICK RD  0110     HOMICIDE
# 3                 019XX W BYRON ST  0620     BURGLARY
# ...

# %%
df['Date'][0]
# Out:
# '08/25/2007 09:22:18 AM'

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y %I:%M:%S %p')

# %%
df_crime = df.copy()
df_crime.head(2)
# Out:
#         ID Case Number                Date                Block  IUCR  \
# 0  5741943    HN549294 2007-08-25 09:22:18   074XX N ROGERS AVE  0560
# 1    25953    JE240540 2021-05-24 15:06:00  020XX N LARAMIE AVE  0110
#
#   Primary Type          Description Location Description Arrest Domestic  ...  \
# 0      ASSAULT               SIMPLE                OTHER  False    False  ...
# 1     HOMICIDE  FIRST DEGREE MURDER               STREET   True    False  ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0  49.0             1.0       08A           NaN          NaN  2007.0
# 1  36.0            19.0       01A     1141387.0    1913179.0  2021.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  08/17/2015 03:03:40 PM        NaN        NaN                            NaN
# 1  11/18/2023 03:39:49 PM  41.917838 -87.755969  (41.917838056, -87.755968972)
#
# [2 rows x 22 columns]

# %% [markdown]
# *original with date as index : df_crime*
# *version for resampling : df_day*

# %%
df_crime = df.set_index('Date')
df_crime.head()
# Out:
#                            ID Case Number                      Block  IUCR  \
# Date
# 2007-08-25 09:22:18   5741943    HN549294         074XX N ROGERS AVE  0560
# 2021-05-24 15:06:00     25953    JE240540        020XX N LARAMIE AVE  0110
# 2021-06-26 09:24:00     26038    JE279849      062XX N MC CORMICK RD  0110
# 2023-11-09 07:30:00  13279676    JG507211           019XX W BYRON ST  0620
# 2023-11-12 07:59:00  13274752    JG501049  086XX S COTTAGE GROVE AVE  0454
#
#                     Primary Type  \
# Date
# 2007-08-25 09:22:18      ASSAULT
# 2021-05-24 15:06:00     HOMICIDE
# 2021-06-26 09:24:00     HOMICIDE
# 2023-11-09 07:30:00     BURGLARY
# 2023-11-12 07:59:00      BATTERY
#
#                                                            Description  \
# Date
# 2007-08-25 09:22:18                                             SIMPLE
# 2021-05-24 15:06:00                                FIRST DEGREE MURDER
# 2021-06-26 09:24:00                                FIRST DEGREE MURDER
# ...

# %%
df_crime.index
# Out:
# DatetimeIndex(['2007-08-25 09:22:18', '2021-05-24 15:06:00',
#                '2021-06-26 09:24:00', '2023-11-09 07:30:00',
#                '2023-11-12 07:59:00', '2002-01-05 21:24:00',
#                '2023-09-06 17:00:00', '2023-08-31 12:00:00',
#                '2023-07-24 21:45:00', '2023-08-27 07:00:00',
#                ...
#                '2006-05-26 15:09:31', '2006-05-27 01:30:00',
#                '2006-07-09 01:55:00', '2006-05-05 22:00:00',
#                '2006-07-03 07:30:00', '2006-04-20 02:15:00',
#                '2006-08-04 02:00:00', '2006-07-23 19:00:30',
#                '2006-07-29 14:30:00',                 'NaT'],
#               dtype='datetime64[ns]', name='Date', length=2611261, freq=None)

# %%
# Original with each row as a crime
df_crime.head(2)
# Out:
#                           ID Case Number                Block  IUCR  \
# Date
# 2007-08-25 09:22:18  5741943    HN549294   074XX N ROGERS AVE  0560
# 2021-05-24 15:06:00    25953    JE240540  020XX N LARAMIE AVE  0110
#
#                     Primary Type          Description Location Description  \
# Date
# 2007-08-25 09:22:18      ASSAULT               SIMPLE                OTHER
# 2021-05-24 15:06:00     HOMICIDE  FIRST DEGREE MURDER               STREET
#
#                     Arrest Domestic    Beat  ...  Ward  Community Area  \
# Date                                         ...
# 2007-08-25 09:22:18  False    False  2422.0  ...  49.0             1.0
# 2021-05-24 15:06:00   True    False  2515.0  ...  36.0            19.0
#
#                      FBI Code X Coordinate  Y Coordinate    Year  \
# Date
# 2007-08-25 09:22:18       08A          NaN           NaN  2007.0
# 2021-05-24 15:06:00       01A    1141387.0     1913179.0  2021.0
#
# ...

# %%
pd.set_option ('display.max_columns', 30)

# %%
#version for resampling
df_day = df.copy()
df_day.head(2)
# Out:
#         ID Case Number                Date                Block  IUCR  \
# 0  5741943    HN549294 2007-08-25 09:22:18   074XX N ROGERS AVE  0560
# 1    25953    JE240540 2021-05-24 15:06:00  020XX N LARAMIE AVE  0110
#
#   Primary Type          Description Location Description Arrest Domestic  \
# 0      ASSAULT               SIMPLE                OTHER  False    False
# 1     HOMICIDE  FIRST DEGREE MURDER               STREET   True    False
#
#      Beat  District  Ward  Community Area FBI Code  X Coordinate  \
# 0  2422.0      24.0  49.0             1.0      08A           NaN
# 1  2515.0      25.0  36.0            19.0      01A     1141387.0
#
#    Y Coordinate    Year              Updated On   Latitude  Longitude  \
# 0           NaN  2007.0  08/17/2015 03:03:40 PM        NaN        NaN
# 1     1913179.0  2021.0  11/18/2023 03:39:49 PM  41.917838 -87.755969
#
#                         Location
# 0                            NaN
# 1  (41.917838056, -87.755968972)

# %%
df_crime.head(2)
# Out:
#                           ID Case Number                Block  IUCR  \
# Date
# 2007-08-25 09:22:18  5741943    HN549294   074XX N ROGERS AVE  0560
# 2021-05-24 15:06:00    25953    JE240540  020XX N LARAMIE AVE  0110
#
#                     Primary Type          Description Location Description  \
# Date
# 2007-08-25 09:22:18      ASSAULT               SIMPLE                OTHER
# 2021-05-24 15:06:00     HOMICIDE  FIRST DEGREE MURDER               STREET
#
#                     Arrest Domestic    Beat  District  Ward  Community Area  \
# Date
# 2007-08-25 09:22:18  False    False  2422.0      24.0  49.0             1.0
# 2021-05-24 15:06:00   True    False  2515.0      25.0  36.0            19.0
#
#                     FBI Code  X Coordinate  Y Coordinate    Year  \
# Date
# 2007-08-25 09:22:18      08A           NaN           NaN  2007.0
# 2021-05-24 15:06:00      01A     1141387.0     1913179.0  2021.0
#
#                                  Updated On   Latitude  Longitude  \
# ...

# %% [markdown]
# **A resampled/converted crime counts version (Each row is 1 day)**

# %%
df_day.head()
# Out:
#          ID Case Number                Date                      Block  IUCR  \
# 0   5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE  0560
# 1     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE  0110
# 2     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD  0110
# 3  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST  0620
# 4  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE  0454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description Arrest Domestic    Beat  District  Ward  \
# ...

# %% [markdown]
# **Topic 1)**
#
# - *Comparing Police Districts:*
# -
# Which district had the most crimes in 2022 -district 8
# Which had the least -district 20?

# %%
crimes_by_year = df_crime.groupby('Year')['Beat'].value_counts(normalize=False)

# %%
crimes_by_year.loc[2022].sum()
# Out:
# 3788

# %%
ax = df_crime.loc['2022', 'District'].value_counts().plot(kind='bar');

# %% [markdown]
# **Topic 2)**
#
#  - Crimes Across the Years:
#
#       -  Is the total number of crimes increasing or decreasing across the years?
#
#       -  Are there any individual crimes that are doing the opposite (e.g., decreasing when overall crime is increasing, or vice-versa)?
# ​

# %%
#df_crime.groupby('Primary Type').value_counts().plot(kind='bar');

# %%
#df_crime['Primary Type']value_counts().plot(kind=bar);

# %%
ax = df_crime['Year'].loc['Description'].value_counts().plot(kind='bar');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:440, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:649, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: Description
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\datetimes.py:704, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     703 try:
# --> 704     parsed, reso = self._parse_with_reso(key)
#     705 except ValueError as err:
#
# ...

# %% [markdown]
# **Topic 4)**
#  - Comparing Months:
#  - Answer the question: ​What months have the most crime? What months have the least?
#  - Answer the question: Are there any individual crimes that do not follow this pattern? If so, which crimes?

# %%
df_m = df_crime.resample('M')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 df_m = df_crime.resample('M')
# ----> 2 df_m.head(2)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\resample.py:204, in Resampler.__getattr__(self, attr)
#     201 if attr in self.obj:
#     202     return self[attr]
# --> 204 return object.__getattribute__(self, attr)
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'head'

# %%
df_m['Date'].loc['Description'].value_counts().plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_m['Date'].loc['Description'].value_counts().plot()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\base.py:248, in SelectionMixin.__getitem__(self, key)
#     246 else:
#     247     if key not in self.obj:
# --> 248         raise KeyError(f"Column not found: {key}")
#     249     subset = self.obj[key]
#     250     ndim = subset.ndim
#
# KeyError: 'Column not found: Date'

# %%
ax = df_crime.loc['Months', 'Description'].value_counts().plot(kind='bar');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:440, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:649, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: Months
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\datetimes.py:704, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     703 try:
# --> 704     parsed, reso = self._parse_with_reso(key)
#     705 except ValueError as err:
#
# ...

# %% [markdown]
# **Topic 5)**
# - Comparing Holidays:
#   - Answer the question: ​What are the top 3 holidays with the largest number of crimes?
#   - Answer the question:  For each of the top 3 holidays with the most crime, what are the top 5 most common crimes on that holiday?
